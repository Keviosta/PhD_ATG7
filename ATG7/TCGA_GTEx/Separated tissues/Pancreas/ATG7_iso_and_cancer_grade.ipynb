# %% [markdown]
# # Import

# %%
import pandas, numpy, seaborn
import scipy, scipy.stats
import matplotlib, matplotlib.pyplot as plt

matplotlib.rcParams.update({'font.size':20, 'xtick.labelsize':20, 'ytick.labelsize':20, 
                            'axes.grid' : True, 'grid.alpha': 0.5, 'grid.linestyle' : ':',
                            'figure.figsize':(12, 8), 'svg.fonttype' : 'none'})

# %%
input_file_directory = '/Users/kja11/OneDrive - Háskóli Íslands/PhD ATG7//0 in_silico/Python/1)data_input/'
output_file_directory = '/Users/kja11/OneDrive - Háskóli Íslands/PhD ATG7/0 in_silico/Python/3)output/'

# %% [markdown]
# # Data dowload

# %%
# %%time
path = 'dataframes_for_input/Transcript expression/'
# download normalized ATG7 isoform expression
df = pandas.read_csv(output_file_directory+ path + 'qndf.tsv', sep = '\t')
df = df.rename(columns = {'sample' : 'transcripts'})
df.head()
# Out:
# Wall time: 1min 11s
#               sample  GTEX-S4Q7-0003-SM-3NM8M  GTEX-QV31-1626-SM-2S1QC  \
# 0  ENST00000625998.2                 2.330439                 2.215577
# 1  ENST00000583693.5                 1.916242                 1.826730
# 2  ENST00000012134.6                 0.498921                 1.712071
# 3  ENST00000403263.5                 2.829238                 2.519280
# 4  ENST00000449352.6                 1.930061                 2.851417
#
#    GTEX-13OW5-0626-SM-5J2N2  GTEX-ZPCL-0126-SM-4WWC8  GTEX-X88G-0426-SM-47JZ5  \
# 0                  0.326033                 0.858464                 2.053532
# 1                  2.113086                 2.132528                 1.538475
# 2                  1.062882                 0.632861                 2.145419
# 3                  1.990125                 2.030941                 2.245568
# 4                  1.984510                 2.316023                 2.755051
#
# ...

# %%
#download the protein coding list.
path = 'xenabrowser_brut_data/TCGA_PAAD/'
clinical_info = pandas.read_csv(input_file_directory+path+"clinical_info.tsv", sep = "\t", index_col=0)
print(clinical_info.shape)
clinical_info.head()
# Out:
# (370, 157)
#                                      case_submitter_id project_id  \
# case_id
# 01775b06-5836-469c-8537-120cb8cc94e9      TCGA-IB-7897  TCGA-PAAD
# 01775b06-5836-469c-8537-120cb8cc94e9      TCGA-IB-7897  TCGA-PAAD
# 02dbd5fa-e31f-4486-8df8-5b851f2e92bd      TCGA-HZ-8315  TCGA-PAAD
# 02dbd5fa-e31f-4486-8df8-5b851f2e92bd      TCGA-HZ-8315  TCGA-PAAD
# 02ef2e1a-5afe-4c00-a3ea-7f4a153f1da4      TCGA-HZ-8636  TCGA-PAAD
#
#                                       age_at_index age_is_obfuscated  \
# case_id
# 01775b06-5836-469c-8537-120cb8cc94e9            53               '--
# 01775b06-5836-469c-8537-120cb8cc94e9            53               '--
# 02dbd5fa-e31f-4486-8df8-5b851f2e92bd            54               '--
# 02dbd5fa-e31f-4486-8df8-5b851f2e92bd            54               '--
# 02ef2e1a-5afe-4c00-a3ea-7f4a153f1da4            58               '--
#
#                                      cause_of_death cause_of_death_source  \
# case_id
# ...

# %%
test_ = clinical_info.columns.str.contains('grade')

# %%
clinical_info.T
# Out:
# case_id               01775b06-5836-469c-8537-120cb8cc94e9  \
# case_submitter_id                             TCGA-IB-7897
# project_id                                       TCGA-PAAD
# age_at_index                                            53
# age_is_obfuscated                                      '--
# cause_of_death                                         '--
# ...                                                    ...
# treatment_frequency                                    '--
# treatment_intent_type                                  '--
# treatment_or_therapy                                    no
# treatment_outcome                                      '--
# treatment_type                 Pharmaceutical Therapy, NOS
#
# case_id               01775b06-5836-469c-8537-120cb8cc94e9  \
# case_submitter_id                             TCGA-IB-7897
# project_id                                       TCGA-PAAD
# age_at_index                                            53
# ...

# %%
info = clinical_info.T
info = info[info.index.str.contains('grade')]
info = info.T
info.columns
# Out:
# Index(['enneking_msts_grade', 'gleason_grade_group', 'gleason_grade_tertiary',
#        'inpc_grade', 'primary_gleason_grade', 'secondary_gleason_grade',
#        'tumor_grade', 'tumor_regression_grade', 'who_cns_grade',
#        'who_nte_grade'],
#       dtype='object')

# %%
print(f'How many samples: {len(info)} \n')
print(f'Value counts: ',info['tumor_grade'].value_counts())
# Out:
# How many samples: 370
#
# Value counts:  not reported    370
# Name: tumor_grade, dtype: int64
